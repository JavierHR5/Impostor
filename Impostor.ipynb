# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import openpyxl
import tabulate
import random
import Funciones_Impostor
import os


Lista_Jugadores=Funciones_Impostor.Jugadores()
Roles=Funciones_Impostor.Impostores(Lista_Jugadores)
Palabra=Funciones_Impostor.Palabra()
print(Palabra)
Funciones_Impostor.Mostrar_rol(Roles,Palabra)
# Out:
# Categorías disponibles: ['Deportistas', 'Películas', 'Actores', 'Series', 'Históricos', 'Países', 'Comidas', 'Animales', 'Marcas']
# Categorías disponibles: ['Deportistas', 'Películas', 'Actores', 'Series', 'Históricos', 'Países', 'Comidas', 'Animales']
# La categoría será: Países
# Alemania
# >>> DEBUG: función mostrar_rol cargada correctamente
# Es el turno de A
# La palabra es: Alemania
# Es el turno de B
# La palabra es: IMPOSTOR
# Es el turno de C
# La palabra es: Alemania
